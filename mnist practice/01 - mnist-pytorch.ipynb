# %%
# ! [ -e /content ] && pip install -Uqq fastbook
# import fastbook
# fastbook.setup_book()
# #hide
# from fastai.vision.all import *
# from fastbook import *

# matplotlib.rc('image', cmap='Greys')

# %%
import torch
from torch import nn

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor, ToPILImage
from torch.utils.data import DataLoader, Subset

# %%
datasets.MNIST
# Out:
# torchvision.datasets.mnist.MNIST

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
class NossonNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.layers = nn.Sequential(
            nn.Linear(28*28, 1024), nn.ReLU(),
            nn.Linear(1024, 512), nn.ReLU(),
            nn.Linear(512, 10)
        )
        
    def forward(self, x):
        x = self.flatten(x)
        logits = self.layers(x)
        return logits

# %%
model = NossonNet().to(device)

# %%
print(model)
# Out:
# NossonNet(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (layers): Sequential(
#     (0): Linear(in_features=784, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
loss_fn = nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
training_data = datasets.MNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# %%
test_data = datasets.MNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)

# %%
bs = 64
train_dl = DataLoader(training_data, batch_size=(bs))
test_dl = DataLoader(test_data, batch_size=(bs))

# %%
for X, y in test_dl:
    print(f"x shape: {X.shape}")
    print(f"y shape: {y.shape} {y.dtype}")
    break
# Out:
# x shape: torch.Size([64, 1, 28, 28])
# y shape: torch.Size([64]) torch.int64

# %%
training_data
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
# sample_idx = 7
# for batch, (X, y) in enumerate(train_dl):
#     print(f'batch number: {batch}')
#     print(f'X shape: {X.shape}')
#     print(f'y shape: {y.shape}')
#     print(f'sample:  {y[sample_idx]}')
#     ToPILImage()(X[sample_idx]).show()
#     break

# %%
def train(dataloader, model, loss_fn, optimizer): # trains a single epoch
    size = len(dataloader.dataset)
    model.train() # set model to train mode - needed for accumulating batch norms averages or training augmentations
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)
        
        pred = model.forward(X)
        loss = loss_fn(pred, y)
        
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        
        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(dataloader, model, loss_fn): # tests a single epoch
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    
    model.eval() # set to eval mode - use accumulated batch norm avg instead of aggregating, no augmentation (unless applying Test Time Augmentation)
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y)
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 5

# %% [markdown]
# ## Train

# %%
for t in range(epochs):
    print(f"Epoch: {t+1} \n-------------")
    train(train_dl, model, loss_fn, optimizer)
    test(test_dl, model, loss_fn)
# Out:
# Epoch: 1
# -------------
# loss: 2.301192  [   64/60000]
# loss: 0.240496  [ 6464/60000]
# loss: 0.181025  [12864/60000]
# loss: 0.267344  [19264/60000]
# loss: 0.120848  [25664/60000]
# loss: 0.317544  [32064/60000]
# loss: 0.130290  [38464/60000]
# loss: 0.198728  [44864/60000]
# loss: 0.251818  [51264/60000]
# loss: 0.153502  [57664/60000]
# Test Error:
#  Accuracy: 95.8%, Avg loss: 0.134917
#
# Epoch: 2
# -------------
# loss: 0.093497  [   64/60000]
# loss: 0.098135  [ 6464/60000]
# loss: 0.114694  [12864/60000]
# loss: 0.076513  [19264/60000]
# loss: 0.061863  [25664/60000]
# loss: 0.137674  [32064/60000]
# loss: 0.055569  [38464/60000]
# loss: 0.138316  [44864/60000]
# loss: 0.122107  [51264/60000]
# loss: 0.090622  [57664/60000]
# Test Error:
#  Accuracy: 97.6%, Avg loss: 0.082836
#
# Epoch: 3
# -------------
# loss: 0.043571  [   64/60000]
# loss: 0.026245  [ 6464/60000]
# loss: 0.022867  [12864/60000]
# loss: 0.081887  [19264/60000]
# loss: 0.017868  [25664/60000]
# loss: 0.079609  [32064/60000]
# loss: 0.045017  [38464/60000]
# loss: 0.069448  [44864/60000]
# loss: 0.065409  [51264/60000]
# loss: 0.044066  [57664/60000]
# Test Error:
#  Accuracy: 96.4%, Avg loss: 0.135076
#
# Epoch: 4
# -------------
# loss: 0.066081  [   64/60000]
# loss: 0.045521  [ 6464/60000]
# loss: 0.041501  [12864/60000]
# loss: 0.137181  [19264/60000]
# loss: 0.011591  [25664/60000]
# loss: 0.059108  [32064/60000]
# loss: 0.058434  [38464/60000]
# loss: 0.045341  [44864/60000]
# loss: 0.076174  [51264/60000]
# loss: 0.030497  [57664/60000]
# Test Error:
#  Accuracy: 96.8%, Avg loss: 0.117446
#
# Epoch: 5
# -------------
# loss: 0.024384  [   64/60000]
# loss: 0.044493  [ 6464/60000]
# loss: 0.030058  [12864/60000]
# loss: 0.017443  [19264/60000]
# loss: 0.047879  [25664/60000]
# loss: 0.057348  [32064/60000]
# loss: 0.020552  [38464/60000]
# loss: 0.005289  [44864/60000]
# loss: 0.072706  [51264/60000]
# loss: 0.045702  [57664/60000]
# Test Error:
#  Accuracy: 97.5%, Avg loss: 0.095981

# %%
training_data[0][0].shape, training_data[0][0], training_data[0][1]
# Out:
# (torch.Size([1, 28, 28]),
#  tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0706, 0.0706, 0.0706,
#            0.4941, 0.5333, 0.6863, 0.1020, 0.6510, 1.0000, 0.9686, 0.4980,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.1176, 0.1412, 0.3686, 0.6039, 0.6667, 0.9922, 0.9922, 0.9922,
#            0.9922, 0.9922, 0.8824, 0.6745, 0.9922, 0.9490, 0.7647, 0.2510,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1922,
#            0.9333, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922,
#            0.9922, 0.9843, 0.3647, 0.3216, 0.3216, 0.2196, 0.1529, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706,
#            0.8588, 0.9922, 0.9922, 0.9922, 0.9922, 0.9922, 0.7765, 0.7137,
#            0.9686, 0.9451, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.3137, 0.6118, 0.4196, 0.9922, 0.9922, 0.8039, 0.0431, 0.0000,
#            0.1686, 0.6039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0549, 0.0039, 0.6039, 0.9922, 0.3529, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.5451, 0.9922, 0.7451, 0.0078, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0431, 0.7451, 0.9922, 0.2745, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.1373, 0.9451, 0.8824, 0.6275,
#            0.4235, 0.0039, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.3176, 0.9412, 0.9922,
#            0.9922, 0.4667, 0.0980, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1765, 0.7294,
#            0.9922, 0.9922, 0.5882, 0.1059, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0627,
#            0.3647, 0.9882, 0.9922, 0.7333, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.9765, 0.9922, 0.9765, 0.2510, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1804, 0.5098,
#            0.7176, 0.9922, 0.9922, 0.8118, 0.0078, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.1529, 0.5804, 0.8980, 0.9922,
#            0.9922, 0.9922, 0.9804, 0.7137, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0941, 0.4471, 0.8667, 0.9922, 0.9922, 0.9922,
#            0.9922, 0.7882, 0.3059, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0902, 0.2588, 0.8353, 0.9922, 0.9922, 0.9922, 0.9922, 0.7765,
#            0.3176, 0.0078, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.6706,
#            0.8588, 0.9922, 0.9922, 0.9922, 0.9922, 0.7647, 0.3137, 0.0353,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.2157, 0.6745, 0.8863, 0.9922,
#            0.9922, 0.9922, 0.9922, 0.9569, 0.5216, 0.0431, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.5333, 0.9922, 0.9922, 0.9922,
#            0.8314, 0.5294, 0.5176, 0.0627, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000]]]),
#  5)

# %%
nn.Flatten()(training_data[0][0]).shape
# Out:
# torch.Size([1, 784])

# %% [markdown]
# ### Test Overfitting:

# %%
train_subset = Subset(training_data, list(range(50)))
test_subset = Subset(test_data, list(range(50)))
subset_train_loader = DataLoader(train_subset, batch_size=(10))
subset_test_loader = DataLoader(test_subset, batch_size=(10))

coopppy = NossonNet().to(device)

# %%
opt = torch.optim.Adam(coopppy.parameters(), lr=1e-3)

# %%
for t in range(epochs*10):
    print(f"Epoch: {t+1} \n-------------")
    train(subset_train_loader, coopppy, loss_fn, opt)
    test(subset_test_loader, coopppy, loss_fn)
# Out:
# Epoch: 1
# -------------
# loss: 2.317378  [   10/   50]
# Test Error:
#  Accuracy: 40.0%, Avg loss: 2.075789
#
# Epoch: 2
# -------------
# loss: 1.742868  [   10/   50]
# Test Error:
#  Accuracy: 52.0%, Avg loss: 1.665648
#
# Epoch: 3
# -------------
# loss: 0.996013  [   10/   50]
# Test Error:
#  Accuracy: 68.0%, Avg loss: 1.218384
#
# Epoch: 4
# -------------
# loss: 0.393345  [   10/   50]
# Test Error:
#  Accuracy: 72.0%, Avg loss: 0.959704
#
# Epoch: 5
# -------------
# loss: 0.126207  [   10/   50]
# Test Error:
#  Accuracy: 70.0%, Avg loss: 0.857299
#
# Epoch: 6
# -------------
# loss: 0.029984  [   10/   50]
# Test Error:
#  Accuracy: 62.0%, Avg loss: 0.899412
#
# Epoch: 7
# -------------
# loss: 0.008620  [   10/   50]
# Test Error:
#  Accuracy: 62.0%, Avg loss: 0.990100
#
# Epoch: 8
# -------------
# loss: 0.003419  [   10/   50]
# Test Error:
#  Accuracy: 60.0%, Avg loss: 1.038255
#
# Epoch: 9
# -------------
# loss: 0.001552  [   10/   50]
# Test Error:
#  Accuracy: 60.0%, Avg loss: 1.056251
#
# Epoch: 10
# -------------
# loss: 0.000871  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.061515
#
# Epoch: 11
# -------------
# loss: 0.000592  [   10/   50]
# Test Error:
#  Accuracy: 66.0%, Avg loss: 1.061830
#
# Epoch: 12
# -------------
# loss: 0.000458  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.060486
#
# Epoch: 13
# -------------
# loss: 0.000386  [   10/   50]
# Test Error:
#  Accuracy: 62.0%, Avg loss: 1.058965
#
# Epoch: 14
# -------------
# loss: 0.000342  [   10/   50]
# Test Error:
#  Accuracy: 62.0%, Avg loss: 1.057567
#
# Epoch: 15
# -------------
# loss: 0.000313  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.056453
#
# Epoch: 16
# -------------
# loss: 0.000292  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.055671
#
# Epoch: 17
# -------------
# loss: 0.000276  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.055144
#
# Epoch: 18
# -------------
# loss: 0.000263  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.054783
#
# Epoch: 19
# -------------
# loss: 0.000252  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.054487
#
# Epoch: 20
# -------------
# loss: 0.000242  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.054284
#
# Epoch: 21
# -------------
# loss: 0.000233  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.054193
#
# Epoch: 22
# -------------
# loss: 0.000225  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.054129
#
# Epoch: 23
# -------------
# loss: 0.000217  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.054094
#
# Epoch: 24
# -------------
# loss: 0.000210  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.054027
#
# Epoch: 25
# -------------
# loss: 0.000203  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.053939
#
# Epoch: 26
# -------------
# loss: 0.000197  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.053862
#
# Epoch: 27
# -------------
# loss: 0.000191  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.053939
#
# Epoch: 28
# -------------
# loss: 0.000185  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.054093
#
# Epoch: 29
# -------------
# loss: 0.000180  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.054235
#
# Epoch: 30
# -------------
# loss: 0.000174  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.054361
#
# Epoch: 31
# -------------
# loss: 0.000169  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.054521
#
# Epoch: 32
# -------------
# loss: 0.000165  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.054783
#
# Epoch: 33
# -------------
# loss: 0.000160  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.055051
#
# Epoch: 34
# -------------
# loss: 0.000156  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.055253
#
# Epoch: 35
# -------------
# loss: 0.000152  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.055458
#
# Epoch: 36
# -------------
# loss: 0.000148  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.055682
#
# Epoch: 37
# -------------
# loss: 0.000144  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.055899
#
# Epoch: 38
# -------------
# loss: 0.000140  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.056135
#
# Epoch: 39
# -------------
# loss: 0.000136  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.056465
#
# Epoch: 40
# -------------
# loss: 0.000133  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.056802
#
# Epoch: 41
# -------------
# loss: 0.000129  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.057137
#
# Epoch: 42
# -------------
# loss: 0.000126  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.057479
#
# Epoch: 43
# -------------
# loss: 0.000123  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.057807
#
# Epoch: 44
# -------------
# loss: 0.000120  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.058125
#
# Epoch: 45
# -------------
# loss: 0.000117  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.058448
#
# Epoch: 46
# -------------
# loss: 0.000114  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.058793
#
# Epoch: 47
# -------------
# loss: 0.000112  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.059183
#
# Epoch: 48
# -------------
# loss: 0.000109  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.059618
#
# Epoch: 49
# -------------
# loss: 0.000106  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.060091
#
# Epoch: 50
# -------------
# loss: 0.000104  [   10/   50]
# Test Error:
#  Accuracy: 64.0%, Avg loss: 1.060531
